# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from scipy import stats
import time

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize  
stop_words = set(stopwords.words("english"))

from lexical_diversity import lex_div as ld

# %% [markdown]
# #### Setting display width to maximum- veryimportant

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Data

# %%
df= pd.read_excel("clean.xlsx")

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Tokenize

# %%
dfcopy = df.copy()

# %%
def tknize(x):
    try:
        return word_tokenize(x)
    except:
        pass

# %%
dfcopy["Comment"] = dfcopy["Comment"].apply(lambda x : tknize(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]

# %% [markdown]
# # Lexical Diversity Measures

# %% [markdown]
# # Simple TTR

# %%
def ttr(x):
    try:
        return ld.ttr(x)
    except:
        pass

# %%
dfcopy["ttr"]=dfcopy["Comment"].apply(lambda x : ttr(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr
# 0  1.000000
# 1  0.770833
# 2  1.000000
# 3  1.000000
# 4  0.928571

# %% [markdown]
# # Root TTR

# %%
def rttr(x):
    try:
        return ld.root_ttr(x)
    except:
        pass

# %%
dfcopy["rttr"]=dfcopy["Comment"].apply(lambda x : rttr(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr      rttr
# 0  1.000000  4.000000
# 1  0.770833  5.340490
# 2  1.000000  4.000000
# 3  1.000000  4.000000
# 4  0.928571  3.474396

# %% [markdown]
# # Log TTR

# %%
def lttr(x):
    try:
        return ld.log_ttr(x)
    except:
        pass

# %%
dfcopy["logttr"]=dfcopy["Comment"].apply(lambda x : lttr(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr      rttr    logttr
# 0  1.000000  4.000000  1.000000
# 1  0.770833  5.340490  0.932764
# 2  1.000000  4.000000  1.000000
# 3  1.000000  4.000000  1.000000
# 4  0.928571  3.474396  0.971919

# %% [markdown]
# # Mass TTR

# %%
#function for mttr and lttr because math error, log involved.
def mttr(x):
    try:
        return ld.maas_ttr(x)
    except:
        pass

# %%
dfcopy["mttr"]=dfcopy["Comment"].apply(lambda x : mttr(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr      rttr    logttr      mttr
# 0  1.000000  4.000000  1.000000  0.000000
# 1  0.770833  5.340490  0.932764  0.039992
# 2  1.000000  4.000000  1.000000  0.000000
# 3  1.000000  4.000000  1.000000  0.000000
# 4  0.928571  3.474396  0.971919  0.024501

# %% [markdown]
# # Mean segmental TTR (MSTTR)

# %%
def msttr(x):
    try:
        return ld.msttr(x)
    except:
        pass

# %%
dfcopy["msttr"]=dfcopy["Comment"].apply(lambda x : msttr(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr      rttr    logttr      mttr     msttr
# 0  1.000000  4.000000  1.000000  0.000000  1.000000
# 1  0.770833  5.340490  0.932764  0.039992  0.770833
# 2  1.000000  4.000000  1.000000  0.000000  1.000000
# 3  1.000000  4.000000  1.000000  0.000000  1.000000
# 4  0.928571  3.474396  0.971919  0.024501  0.928571

# %% [markdown]
# # Moving average TTR (MATTR)

# %%
def mattr(x):
    try:
        return ld.mattr(x)
    except:
        pass

# %%
dfcopy["mattr"]=dfcopy["Comment"].apply(lambda x : mattr(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr      rttr    logttr      mttr     msttr     mattr
# 0  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000
# 1  0.770833  5.340490  0.932764  0.039992  0.770833  0.770833
# 2  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000
# 3  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000
# 4  0.928571  3.474396  0.971919  0.024501  0.928571  0.928571

# %% [markdown]
# # Hypergeometric distribution D (HDD)

# %%
def hdd(x):
    try:
        return ld.hdd(x)
    except:
        pass

# %%
dfcopy["hdd"]=dfcopy["Comment"].apply(lambda x : hdd(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr      rttr    logttr      mttr     msttr     mattr       hdd
# 0  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 1  0.770833  5.340490  0.932764  0.039992  0.770833  0.770833  0.790056
# 2  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 3  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 4  0.928571  3.474396  0.971919  0.024501  0.928571  0.928571  0.000000

# %% [markdown]
# # Measure of lexical textual diversity (MTLD)

# %%
def mtld(x):
    try:
        return ld.mtld(x)
    except:
        pass

# %%
dfcopy["mtld"]=dfcopy["Comment"].apply(lambda x : mtld(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr      rttr    logttr      mttr     msttr     mattr       hdd  \
# 0  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 1  0.770833  5.340490  0.932764  0.039992  0.770833  0.770833  0.790056
# 2  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 3  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 4  0.928571  3.474396  0.971919  0.024501  0.928571  0.928571  0.000000
#
#         mtld
# 0   0.000000
# 1  58.647273
# 2   0.000000
# 3   0.000000
# 4  54.880000

# %% [markdown]
# # Measure of lexical textual diversity (moving average, wrap)

# %%
def mtld_mawrap(x):
    try:
        return ld.mtld_ma_wrap(x)
    except:
        pass

# %%
dfcopy["mtld_mawrap"]=dfcopy["Comment"].apply(lambda x : mtld_mawrap(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr      rttr    logttr      mttr     msttr     mattr       hdd  \
# 0  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 1  0.770833  5.340490  0.932764  0.039992  0.770833  0.770833  0.790056
# 2  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 3  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 4  0.928571  3.474396  0.971919  0.024501  0.928571  0.928571  0.000000
#
#         mtld  mtld_mawrap
# 0   0.000000    23.000000
# 1  58.647273    47.088889
# 2   0.000000    23.000000
# 3   0.000000    23.000000
# 4  54.880000    19.000000

# %% [markdown]
# # Measure of lexical textual diversity (moving average, bi-directional)

# %%
def mtld_mabid(x):
    try:
        return ld.mtld_ma_bid(x)
    except:
        pass

# %%
dfcopy["mtld_mabid"]=dfcopy["Comment"].apply(lambda x : mtld_mabid(x) )

# %%
dfcopy.head()
# Out:
#                name  \
# 0       lucid conch
# 1  steven armstrong
# 2  willieam sandren
# 3      niles graham
# 4     irfan nasyriq
#
#                                                                                                                                                                                                                                                                                 Comment  \
# 0                                                                                                                                                            [The, wandering, whittler, lightly, now, because, whistle, quietly, listen, for, a, little, crow, Feathered, quickly, fly]
# 1  [Neil, says, there, is, no, reason, the, earth, goes, around, the, sun, in, the, time, it, does, withing, a, third, of, an, increment, for, leap, years, But, why, isnt, he, saying, there, has, to, be, a, reason, the, earth, orbits, the, sun, in, a, slight, off, beat, pattern]
# 2                                                                                                                                                [The, clever, cardboard, numerically, please, because, dimple, largely, intend, behind, a, useful, chime, wistful, fluttering, gemini]
# 3                                                                                                                                                   [The, tasty, bonsai, indirectly, scream, because, uncle, approximately, strip, near, a, onerous, crate, knotty, disastrous, collar]
# 4                                                                                                                                                                                                         [now, the, fans, of, jre, knows, that, the, earth, is, shape, like, a, skull]
#
#         ttr      rttr    logttr      mttr     msttr     mattr       hdd  \
# 0  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 1  0.770833  5.340490  0.932764  0.039992  0.770833  0.770833  0.790056
# 2  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 3  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 4  0.928571  3.474396  0.971919  0.024501  0.928571  0.928571  0.000000
#
#         mtld  mtld_mawrap  mtld_mabid
# 0   0.000000    23.000000         0.0
# 1  58.647273    47.088889         0.0
# 2   0.000000    23.000000         0.0
# 3   0.000000    23.000000         0.0
# 4  54.880000    19.000000         0.0

# %% [markdown]
# # Results

# %%
neilresults = dfcopy[["ttr","rttr","logttr","mttr","msttr","mattr","hdd","mtld","mtld_mawrap","mtld_mabid"]]

# %%
neilresults.head()
# Out:
#         ttr      rttr    logttr      mttr     msttr     mattr       hdd  \
# 0  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 1  0.770833  5.340490  0.932764  0.039992  0.770833  0.770833  0.790056
# 2  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 3  1.000000  4.000000  1.000000  0.000000  1.000000  1.000000  0.000000
# 4  0.928571  3.474396  0.971919  0.024501  0.928571  0.928571  0.000000
#
#         mtld  mtld_mawrap  mtld_mabid
# 0   0.000000    23.000000         0.0
# 1  58.647273    47.088889         0.0
# 2   0.000000    23.000000         0.0
# 3   0.000000    23.000000         0.0
# 4  54.880000    19.000000         0.0

# %%
neilresults.describe()
# Out:
#                 ttr          rttr        logttr          mttr         msttr  \
# count  14024.000000  14024.000000  14023.000000  14023.000000  14024.000000
# mean       0.932228      3.828348      0.963415      0.016554      0.940572
# std        0.098059      1.700927      0.122523      0.060808      0.081528
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.888889      2.645751      0.960253      0.000000      0.893333
# 50%        1.000000      3.474396      1.000000      0.000000      1.000000
# 75%        1.000000      4.669738      1.000000      0.026180      1.000000
# max        1.000000     16.694483      1.000000      3.321928      1.000000
#
#               mattr           hdd          mtld   mtld_mawrap    mtld_mabid
# count  14024.000000  14024.000000  14024.000000  14024.000000  14024.000000
# mean       0.940273      0.124081     39.306576     26.551656      3.744586
# std        0.081729      0.302192     57.187813     26.247280     16.435732
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.891304      0.000000      0.000000     10.000000      0.000000
# 50%        1.000000      0.000000      0.000000     19.000000      0.000000
# 75%        1.000000      0.000000     69.978462     33.128968      0.000000
# max        1.000000      0.979293    567.000000    257.000000    233.847826

# %%
#neilresults.to_csv("neilresults", index=False, encoding = 'utf-8')
