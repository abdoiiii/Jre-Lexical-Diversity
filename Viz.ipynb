# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from scipy import stats
import time

# %%
pd.set_option('display.max_colwidth', None)

# %%
df1= pd.read_csv("elonresults")
df2= pd.read_csv("alexresults")
df3= pd.read_csv("neilresults")

# %%
df1.describe()
# Out:
#                 ttr          rttr        logttr          mttr         msttr  \
# count  41438.000000  41438.000000  41438.000000  41438.000000  41438.000000
# mean       0.933615      3.782535      0.956743      0.018423      0.941641
# std        0.099162      1.738020      0.146969      0.088631      0.083343
# min        0.001106      0.033260      0.000000      0.000000      0.020000
# 25%        0.888889      2.645751      0.960253      0.000000      0.894737
# 50%        1.000000      3.464102      1.000000      0.000000      1.000000
# 75%        1.000000      4.630462      1.000000      0.024967      1.000000
# max        1.000000     16.315153      1.000000      3.321928      1.000000
#
#               mattr           hdd          mtld   mtld_mawrap    mtld_mabid
# count  41438.000000  41438.000000  41438.000000  41438.000000  41438.000000
# mean       0.941413      0.118447     39.130779     26.155836      3.570056
# ...

# %%
df1.mtld.idxmax()
# Out:
# 2518

# %%
df1.loc[df1.mtld > 500].count()
# Out:
# ttr            13
# rttr           13
# logttr         13
# mttr           13
# msttr          13
# mattr          13
# hdd            13
# mtld           13
# mtld_mawrap    13
# mtld_mabid     13
# dtype: int64

# %%
plt.scatter(df1.mtld, df1.index  , s=1 ,edgecolors= "black")
plt.xlabel("MTLD")
plt.ylabel("User")


#plt.xticks(np.arange(min(df1.mtld), max(df1.mtld)+1, 1.0))
# Out:
# Text(0, 0.5, 'User')

# %%
plt.scatter(df2.mtld, df2.index  , s=1)
plt.xlabel("MTLD")
plt.ylabel("User")
# Out:
# Text(0, 0.5, 'User')

# %%
plt.scatter(df3.mtld, df3.index  , s=1)

plt.xlabel("MTLD")
plt.ylabel("User")
# Out:
# Text(0, 0.5, 'User')
